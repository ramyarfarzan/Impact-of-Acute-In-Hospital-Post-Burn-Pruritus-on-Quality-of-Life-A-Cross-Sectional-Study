# %%
# Import required libraries
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset (adjust the file name/path as needed)
data = pd.read_csv('Final_data.csv')

def normality_tests(data):
    results = []
    
    for column in data.select_dtypes(include=[np.number]).columns:
        values = data[column].dropna()
        
        if len(values) > 3:  # Shapiro-Wilk requires at least 3 values
            ks_stat, ks_p = stats.kstest(values, 'norm', args=(values.mean(), values.std()))
            sw_stat, sw_p = stats.shapiro(values)
            
            normality = "Normal (p > 0.05)" if ks_p > 0.05 and sw_p > 0.05 else "Not Normal (p ≤ 0.05)"
            results.append([column, ks_p, sw_p, normality])
        else:
            results.append([column, None, None, "Insufficient Data"])
    
    results_df = pd.DataFrame(results, columns=["Variable", "KS p-value", "SW p-value", "Normality"])
    return results_df


normality_results = normality_tests(data)
print(normality_results)

def non_parametric_tests(data):
    results = []
    
    numeric_cols = data.select_dtypes(include=[np.number]).columns
    categorical_cols = data.select_dtypes(include=['object', 'category']).columns
    
    # Mann-Whitney U Test (for two independent groups)
    for cat_col in categorical_cols:
        if data[cat_col].nunique() == 2:  # Ensure only two unique groups
            for num_col in numeric_cols:
                group1 = data[data[cat_col] == data[cat_col].unique()[0]][num_col].dropna()
                group2 = data[data[cat_col] == data[cat_col].unique()[1]][num_col].dropna()
                
                if len(group1) > 0 and len(group2) > 0:
                    mwu_stat, mwu_p = stats.mannwhitneyu(group1, group2)
                    interpretation = "Significant" if mwu_p < 0.05 else "Not Significant"
                    results.append([f"Mann-Whitney U Test ({cat_col} vs {num_col})", round(mwu_stat, 4), round(mwu_p, 4), interpretation])
    
    # Kruskal-Wallis H Test (for multiple independent groups)
    for cat_col in categorical_cols:
        if data[cat_col].nunique() > 2:  # Ensure multiple groups
            for num_col in numeric_cols:
                groups = [group[num_col].dropna().values for _, group in data.groupby(cat_col) if len(group) > 0]
                
                if len(groups) > 1:
                    kw_stat, kw_p = stats.kruskal(*groups)
                    interpretation = "Significant" if kw_p < 0.05 else "Not Significant"
                    results.append([f"Kruskal-Wallis H Test ({cat_col} vs {num_col})", round(kw_stat, 4), round(kw_p, 4), interpretation])
    
    # Spearman’s Rank Correlation (only for QoL_Score vs other numeric variables)
    if 'QoL_Score' in numeric_cols:
        for num_col in numeric_cols:
            if num_col != 'QoL_Score':
                spearman_corr, spearman_p = stats.spearmanr(data['QoL_Score'].dropna(), data[num_col].dropna())
                if abs(spearman_corr) > 0.5:
                    interpretation = "Strong Correlation"
                elif abs(spearman_corr) > 0.3:
                    interpretation = "Moderate Correlation"
                else:
                    interpretation = "Weak Correlation"
                results.append([f"Spearman’s Rank Correlation (QoL_Score vs {num_col})", round(spearman_corr, 4), round(spearman_p, 4), interpretation])
    
    # Convert results to DataFrame
    results_df = pd.DataFrame(results, columns=["Test", "Statistic", "p-value", "Interpretation"])
    return results_df

# Run the function
non_parametric_results = non_parametric_tests(data)
print(non_parametric_results)



def parametric_tests(data):
    results = []
    
    numeric_cols = data.select_dtypes(include=[np.number]).columns
    categorical_cols = data.select_dtypes(include=['object', 'category']).columns
    
    # T-test (Independent Samples T-test)
    for cat_col in categorical_cols:
        if data[cat_col].nunique() == 2:  # Ensure only two unique groups
            for num_col in numeric_cols:
                group1 = data[data[cat_col] == data[cat_col].unique()[0]][num_col].dropna()
                group2 = data[data[cat_col] == data[cat_col].unique()[1]][num_col].dropna()
                
                if len(group1) > 0 and len(group2) > 0:
                    t_stat, t_p = stats.ttest_ind(group1, group2)
                    interpretation = "Significant" if t_p < 0.05 else "Not Significant"
                    results.append([f"T-test ({cat_col} vs {num_col})", round(t_stat, 4), round(t_p, 4), interpretation])
    
    # Chi-Square Test (for association between two categorical variables)
    for cat_col1 in categorical_cols:
        for cat_col2 in categorical_cols:
            if cat_col1 != cat_col2:
                contingency_table = pd.crosstab(data[cat_col1], data[cat_col2])
                chi2_stat, chi2_p, _, _ = stats.chi2_contingency(contingency_table)
                interpretation = "Associated" if chi2_p < 0.05 else "Not Associated"
                results.append([f"Chi-Square Test ({cat_col1} vs {cat_col2})", round(chi2_stat, 4), round(chi2_p, 4), interpretation])
    
    # Pearson Correlation (only for QoL_Score vs other numeric variables)
    if 'QoL_Score' in numeric_cols:
        for num_col in numeric_cols:
            if num_col != 'QoL_Score':
                pearson_corr, pearson_p = stats.pearsonr(data['QoL_Score'].dropna(), data[num_col].dropna())
                interpretation = "Strong" if abs(pearson_corr) > 0.5 else "Weak"
                results.append([f"Pearson Correlation (QoL_Score vs {num_col})", round(pearson_corr, 4), round(pearson_p, 4), interpretation])
    
    # Convert results to DataFrame
    results_df = pd.DataFrame(results, columns=["Test", "Statistic", "p-value", "Interpretation"])
    return results_df

parametric_results = parametric_tests(data)
print(parametric_results)

# Save each table to a separate text file
normality_results.to_csv('normality_results1.txt', index=False, sep='\t')
non_parametric_results.to_csv('non_parametric_results1.txt', index=False, sep='\t')
parametric_results.to_csv('parametric_results1.txt', index=False, sep='\t')

print("Tables have been saved to text files.")
# Out:
#                    Variable  KS p-value    SW p-value              Normality
# 0                       Age    0.772930  1.547713e-01      Normal (p > 0.05)
# 1               TBSA_Burned    0.000024  1.515539e-14  Not Normal (p ≤ 0.05)
# 2             Itch_Severity    0.000005  2.279278e-11  Not Normal (p ≤ 0.05)
# 3             Itch_Duration    0.000152  3.426098e-09  Not Normal (p ≤ 0.05)
# 4                 QoL_Score    0.048300  1.187934e-07  Not Normal (p ≤ 0.05)
# 5  Hospitalization_Duration    0.000042  3.925278e-09  Not Normal (p ≤ 0.05)
#                                                  Test   Statistic  p-value  \
# 0                 Mann-Whitney U Test (Gender vs Age)   8317.0000   0.2976
# 1         Mann-Whitney U Test (Gender vs TBSA_Burned)   8963.5000   0.9824
# 2       Mann-Whitney U Test (Gender vs Itch_Severity)   9156.5000   0.7768
# 3       Mann-Whitney U Test (Gender vs Itch_Duration)   9448.5000   0.4559
# 4           Mann-Whitney U Test (Gender vs QoL_Score)   8809.0000   0.7905
# 5   Mann-Whitney U Test (Gender vs Hospitalization...   8460.0000   0.4129
# 6             Mann-Whitney U Test (Burn_Depth vs Age)   7919.0000   0.7180
# 7     Mann-Whitney U Test (Burn_Depth vs TBSA_Burned)   8725.5000   0.3302
# 8   Mann-Whitney U Test (Burn_Depth vs Itch_Severity)   8994.5000   0.1520
# 9   Mann-Whitney U Test (Burn_Depth vs Itch_Duration)   8300.0000   0.7872
# 10      Mann-Whitney U Test (Burn_Depth vs QoL_Score)   9000.0000   0.1534
# 11  Mann-Whitney U Test (Burn_Depth vs Hospitaliza...  13971.5000   0.0000
# 12           Mann-Whitney U Test (Itch_Report vs Age)   6410.5000   0.7478
# 13   Mann-Whitney U Test (Itch_Report vs TBSA_Burned)   5514.0000   0.1697
# 14  Mann-Whitney U Test (Itch_Report vs Itch_Sever...      0.0000   0.0000
# 15  Mann-Whitney U Test (Itch_Report vs Itch_Durat...      0.0000   0.0000
# 16     Mann-Whitney U Test (Itch_Report vs QoL_Score)    972.0000   0.0000
# 17  Mann-Whitney U Test (Itch_Report vs Hospitaliz...   6309.5000   0.8958
# 18                 Kruskal-Wallis H Test (PID vs Age)    267.0000   0.4885
# 19         Kruskal-Wallis H Test (PID vs TBSA_Burned)    267.0000   0.4885
# 20       Kruskal-Wallis H Test (PID vs Itch_Severity)    267.0000   0.4885
# 21       Kruskal-Wallis H Test (PID vs Itch_Duration)    267.0000   0.4885
# 22           Kruskal-Wallis H Test (PID vs QoL_Score)    267.0000   0.4885
# 23  Kruskal-Wallis H Test (PID vs Hospitalization_...    267.0000   0.4885
# 24       Kruskal-Wallis H Test (Burn_Location vs Age)      3.4970   0.6238
# 25  Kruskal-Wallis H Test (Burn_Location vs TBSA_B...    104.5118   0.0000
# 26  Kruskal-Wallis H Test (Burn_Location vs Itch_S...     48.3350   0.0000
# 27  Kruskal-Wallis H Test (Burn_Location vs Itch_D...     36.6880   0.0000
# 28  Kruskal-Wallis H Test (Burn_Location vs QoL_Sc...     55.7529   0.0000
# 29  Kruskal-Wallis H Test (Burn_Location vs Hospit...     48.1851   0.0000
# 30   Kruskal-Wallis H Test (Accident_Location vs Age)      6.7447   0.0343
# 31  Kruskal-Wallis H Test (Accident_Location vs TB...      3.0321   0.2196
# 32  Kruskal-Wallis H Test (Accident_Location vs It...      0.7818   0.6764
# 33  Kruskal-Wallis H Test (Accident_Location vs It...      0.4626   0.7935
# 34  Kruskal-Wallis H Test (Accident_Location vs Qo...      2.8285   0.2431
# 35  Kruskal-Wallis H Test (Accident_Location vs Ho...      0.4534   0.7972
# 36          Kruskal-Wallis H Test (Burn_Cause vs Age)      2.0167   0.3648
# 37  Kruskal-Wallis H Test (Burn_Cause vs TBSA_Burned)      2.8786   0.2371
# 38  Kruskal-Wallis H Test (Burn_Cause vs Itch_Seve...      0.9503   0.6218
# 39  Kruskal-Wallis H Test (Burn_Cause vs Itch_Dura...      1.3503   0.5091
# 40    Kruskal-Wallis H Test (Burn_Cause vs QoL_Score)      1.5324   0.4648
# 41  Kruskal-Wallis H Test (Burn_Cause vs Hospitali...      1.0556   0.5899
# 42      Kruskal-Wallis H Test (Other_Diseases vs Age)      5.6238   0.2291
# 43  Kruskal-Wallis H Test (Other_Diseases vs TBSA_...      3.6550   0.4547
# 44  Kruskal-Wallis H Test (Other_Diseases vs Itch_...      0.2943   0.9902
# 45  Kruskal-Wallis H Test (Other_Diseases vs Itch_...      0.6931   0.9522
# 46  Kruskal-Wallis H Test (Other_Diseases vs QoL_S...      1.3313   0.8560
# 47  Kruskal-Wallis H Test (Other_Diseases vs Hospi...      4.9021   0.2975
# 48       Kruskal-Wallis H Test (Itch_Location vs Age)      5.9611   0.4276
# 49  Kruskal-Wallis H Test (Itch_Location vs TBSA_B...     53.4060   0.0000
# 50  Kruskal-Wallis H Test (Itch_Location vs Itch_S...    169.4771   0.0000
# 51  Kruskal-Wallis H Test (Itch_Location vs Itch_D...    155.1661   0.0000
# 52  Kruskal-Wallis H Test (Itch_Location vs QoL_Sc...    128.2767   0.0000
# 53  Kruskal-Wallis H Test (Itch_Location vs Hospit...     36.7321   0.0000
# 54     Spearman’s Rank Correlation (QoL_Score vs Age)      0.0125   0.8389
# 55  Spearman’s Rank Correlation (QoL_Score vs TBSA...      0.6199   0.0000
# 56  Spearman’s Rank Correlation (QoL_Score vs Itch...      0.8357   0.0000
# 57  Spearman’s Rank Correlation (QoL_Score vs Itch...      0.7888   0.0000
# 58  Spearman’s Rank Correlation (QoL_Score vs Hosp...      0.4051   0.0000
#
#           Interpretation
# 0        Not Significant
# 1        Not Significant
# 2        Not Significant
# 3        Not Significant
# 4        Not Significant
# 5        Not Significant
# 6        Not Significant
# 7        Not Significant
# 8        Not Significant
# 9        Not Significant
# 10       Not Significant
# 11           Significant
# 12       Not Significant
# 13       Not Significant
# 14           Significant
# 15           Significant
# 16           Significant
# 17       Not Significant
# 18       Not Significant
# 19       Not Significant
# 20       Not Significant
# 21       Not Significant
# 22       Not Significant
# 23       Not Significant
# 24       Not Significant
# 25           Significant
# 26           Significant
# 27           Significant
# 28           Significant
# 29           Significant
# 30           Significant
# 31       Not Significant
# 32       Not Significant
# 33       Not Significant
# 34       Not Significant
# 35       Not Significant
# 36       Not Significant
# 37       Not Significant
# 38       Not Significant
# 39       Not Significant
# 40       Not Significant
# 41       Not Significant
# 42       Not Significant
# 43       Not Significant
# 44       Not Significant
# 45       Not Significant
# 46       Not Significant
# 47       Not Significant
# 48       Not Significant
# 49           Significant
# 50           Significant
# 51           Significant
# 52           Significant
# 53           Significant
# 54      Weak Correlation
# 55    Strong Correlation
# 56    Strong Correlation
# 57    Strong Correlation
# 58  Moderate Correlation
#                                                  Test  Statistic  p-value  \
# 0                              T-test (Gender vs Age)    -1.0530   0.2933
# 1                      T-test (Gender vs TBSA_Burned)     0.3193   0.7497
# 2                    T-test (Gender vs Itch_Severity)     0.5352   0.5929
# 3                    T-test (Gender vs Itch_Duration)     0.9250   0.3558
# 4                        T-test (Gender vs QoL_Score)    -0.0335   0.9733
# ..                                                ...        ...      ...
# 90             Pearson Correlation (QoL_Score vs Age)     0.0111   0.8563
# 91     Pearson Correlation (QoL_Score vs TBSA_Burned)     0.6202   0.0000
# 92   Pearson Correlation (QoL_Score vs Itch_Severity)     0.8324   0.0000
# 93   Pearson Correlation (QoL_Score vs Itch_Duration)     0.7969   0.0000
# 94  Pearson Correlation (QoL_Score vs Hospitalizat...     0.4183   0.0000
#
#      Interpretation
# 0   Not Significant
# 1   Not Significant
# 2   Not Significant
# 3   Not Significant
# 4   Not Significant
# ..              ...
# 90             Weak
# 91           Strong
# 92           Strong
# 93           Strong
# 94             Weak
#
# [95 rows x 4 columns]
# Tables have been saved to text files.
